# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarvasekar/ML_Projects/blob/main/SoftwareDefectPredictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
dataset=pd.read_csv('/content/train.csv')

# %%
dataset.head()
# Out:
#    id   loc  v(g)  ev(g)  iv(g)     n       v     l      d      i  ...  \
# 0   0  22.0   3.0    1.0    2.0  60.0  278.63  0.06  19.56  14.25  ...
# 1   1  14.0   2.0    1.0    2.0  32.0  151.27  0.14   7.00  21.11  ...
# 2   2  11.0   2.0    1.0    2.0  45.0  197.65  0.11   8.05  22.76  ...
# 3   3   8.0   1.0    1.0    1.0  23.0   94.01  0.19   5.25  17.86  ...
# 4   4  11.0   2.0    1.0    2.0  17.0   60.94  0.18   5.63  12.44  ...
#
#    lOCode  lOComment  lOBlank  locCodeAndComment  uniq_Op  uniq_Opnd  \
# 0      17          1        1                  0     16.0        9.0
# 1      11          0        1                  0     11.0       11.0
# 2       8          0        1                  0     12.0       11.0
# 3       4          0        2                  0      8.0        6.0
# 4       7          0        2                  0      7.0        6.0
#
#    total_Op  total_Opnd  branchCount  defects
# 0      38.0        22.0          5.0    False
# ...

# %%
dataset.replace({"defects":{'False':0,'True':1}}, inplace=True )

# %%
dataset.head()
# Out:
#    id   loc  v(g)  ev(g)  iv(g)     n       v     l      d      i  ...  \
# 0   0  22.0   3.0    1.0    2.0  60.0  278.63  0.06  19.56  14.25  ...
# 1   1  14.0   2.0    1.0    2.0  32.0  151.27  0.14   7.00  21.11  ...
# 2   2  11.0   2.0    1.0    2.0  45.0  197.65  0.11   8.05  22.76  ...
# 3   3   8.0   1.0    1.0    1.0  23.0   94.01  0.19   5.25  17.86  ...
# 4   4  11.0   2.0    1.0    2.0  17.0   60.94  0.18   5.63  12.44  ...
#
#    lOCode  lOComment  lOBlank  locCodeAndComment  uniq_Op  uniq_Opnd  \
# 0      17          1        1                  0     16.0        9.0
# 1      11          0        1                  0     11.0       11.0
# 2       8          0        1                  0     12.0       11.0
# 3       4          0        2                  0      8.0        6.0
# 4       7          0        2                  0      7.0        6.0
#
#    total_Op  total_Opnd  branchCount  defects
# 0      38.0        22.0          5.0    False
# ...

# %%
X=dataset.drop(columns={'id','defects'},axis=1)

# %%
print(X)
# Out:
#           loc  v(g)  ev(g)  iv(g)      n        v     l      d      i  \
# 0        22.0   3.0    1.0    2.0   60.0   278.63  0.06  19.56  14.25
# 1        14.0   2.0    1.0    2.0   32.0   151.27  0.14   7.00  21.11
# 2        11.0   2.0    1.0    2.0   45.0   197.65  0.11   8.05  22.76
# 3         8.0   1.0    1.0    1.0   23.0    94.01  0.19   5.25  17.86
# 4        11.0   2.0    1.0    2.0   17.0    60.94  0.18   5.63  12.44
# ...       ...   ...    ...    ...    ...      ...   ...    ...    ...
# 101758   10.0   2.0    1.0    1.0   28.0   122.98  0.15   6.60  18.63
# 101759   27.0   5.0    4.0    1.0  107.0   559.93  0.06  18.00  34.17
# 101760   26.0   1.0    1.0    1.0   83.0   360.17  0.04  22.75  12.56
# 101761   10.0   2.0    1.0    2.0   43.0   191.76  0.15   6.46  29.53
# 101762  136.0  18.0   18.0    1.0  296.0  1704.57  0.02  44.82  44.08
#
#                e  ...        t  lOCode  lOComment  lOBlank  locCodeAndComment  \
# ...

# %%
Y=dataset['defects']
print(Y)
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 101758    False
# 101759    False
# 101760    False
# 101761    False
# 101762    False
# Name: defects, Length: 101763, dtype: bool

# %%
scaler=StandardScaler()
scaler.fit(X)
standardized_data=scaler.transform(X)
X=standardized_data
print(X)
# Out:
# [[-0.28108282 -0.31549702 -0.39838633 ... -0.18776212 -0.24060855
#   -0.33578367]
#  [-0.42760261 -0.44206622 -0.39838633 ... -0.37908167 -0.35219708
#   -0.47455019]
#  [-0.48254753 -0.44206622 -0.39838633 ... -0.2834219  -0.31035138
#   -0.47455019]
#  ...
#  [-0.20782293 -0.56863542 -0.39838633 ... -0.06340441 -0.15691715
#   -0.61331671]
#  [-0.50086251 -0.44206622 -0.39838633 ... -0.32168581 -0.28245425
#   -0.47455019]
#  [ 1.80682418  1.583041    3.27233773 ...  0.9984191   1.33557943
#    1.74571413]]

# %%
classifier=svm.SVC(kernel='linear')
classifier.fit(X,Y)
# Out:
# SVC(kernel='linear')

# %%
X_test=pd.read_csv("/content/test.csv")

# %%
print(X_test)
# Out:
# [[-0.08703423 -0.06791786 -0.39810657 ...  0.27182298  0.23578527
#   -0.06425941]
#  [-0.19457362  0.29627789  1.10199993 ...  0.11067129  0.12582837
#    0.32680193]
#  [ 1.65151933  0.66047364  0.887699   ...  2.60378279  2.80602766
#    0.71786327]
#  ...
#  [-0.24834332 -0.4321136  -0.39810657 ... -0.2116321  -0.30025459
#   -0.45532075]
#  [-0.35588271 -0.4321136  -0.39810657 ... -0.27798868 -0.24527614
#   -0.45532075]
#  [ 1.13174558  1.14606796  1.53060179 ... -0.55289451 -0.5476576
#    1.23927839]]

# %%
X_test=X_test.drop(columns='id')

# %%
scaler.fit(X_test)
standardized_data=scaler.transform(X_test)
X_test=standardized_data
print(X_test)
# Out:
# [[-0.08703423 -0.06791786 -0.39810657 ...  0.27182298  0.23578527
#   -0.06425941]
#  [-0.19457362  0.29627789  1.10199993 ...  0.11067129  0.12582837
#    0.32680193]
#  [ 1.65151933  0.66047364  0.887699   ...  2.60378279  2.80602766
#    0.71786327]
#  ...
#  [-0.24834332 -0.4321136  -0.39810657 ... -0.2116321  -0.30025459
#   -0.45532075]
#  [-0.35588271 -0.4321136  -0.39810657 ... -0.27798868 -0.24527614
#   -0.45532075]
#  [ 1.13174558  1.14606796  1.53060179 ... -0.55289451 -0.5476576
#    1.23927839]]

# %%
test_prediction=classifier.predict(X_test)
print(test_prediction)
# Out:
# [False False  True ... False False  True]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-c8ff277ea5c9> in <cell line: 1>()
# ----> 1 X_test.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'
